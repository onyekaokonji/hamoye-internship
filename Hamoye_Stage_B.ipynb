# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
data = pd.read_csv("energydata_complete.csv")

# %%
data.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
lr = LinearRegression()

# %%
data.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
data.drop(['date', 'lights'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
D = data.drop('Appliances', axis = 1)
T = data['Appliances']

# %%
data.columns
# Out:
# Index(['Appliances', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4',
#        'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9',
#        'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
scaler = MinMaxScaler()

# %%
data = scaler.fit_transform(D)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(D, T, test_size = 0.3, random_state = 42)

# %%
X_train
# Out:
#               T1       RH_1         T2       RH_2         T3   RH_3     T4  \
# 9129   21.500000  35.626667  17.790000  40.590000  21.700000  35.26  20.39
# 2453   19.500000  44.560000  18.700000  44.290000  19.823333  44.50  18.10
# 9152   20.790000  35.400000  16.890000  42.030000  21.700000  36.00  19.70
# 12694  22.100000  43.260000  19.963333  45.500000  23.390000  39.79  21.10
# 16952  24.700000  42.360000  29.856667  31.790000  26.171429  38.59  25.10
# ...          ...        ...        ...        ...        ...    ...    ...
# 11284  21.760000  40.900000  19.390000  43.090000  23.000000  39.00  21.50
# 11964  22.390000  43.700000  22.000000  42.066667  22.700000  41.23  21.29
# 5390   20.290000  35.700000  18.200000  37.590000  20.100000  37.59  18.20
# 860    21.790000  35.560000  20.434000  35.116000  21.200000  36.90  21.10
# 15795  21.323333  37.730000  19.890000  38.566667  22.700000  36.59  19.70
#
# ...

# %%
X_train.columns
# Out:
# Index(['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5',
#        'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'T_out',
#        'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility', 'Tdewpoint', 'rv1',
#        'rv2'],
#       dtype='object')

# %%
running = lr.fit(X_train, Y_train)

# %%
pred = running.predict(X_test)

# %%
pred
# Out:
# array([ 45.54761868, 271.20410666,  46.38025696, ...,  83.23836265,
#        117.34588177,  71.22751965])

# %% [markdown]
# ### Q: What is the Mean Absolute Error (in two decimal places)?

# %%
mean_absolute_error(Y_test, pred)
# Out:
# 53.642977655849585

# %% [markdown]
# ### Q: What is the Root Mean Squared Error (in three decimal places)?

# %%
mean_squared_error(Y_test, pred)
# Out:
# 8768.535925051976

# %% [markdown]
# ### Q: What is the Residual Sum of Squares (in two decimal places)?

# %%
np.sqrt(mean_squared_error(Y_test, pred))
# Out:
# 93.6404609399803

# %% [markdown]
# ### Q: Obtain the feature weights from your linear model above. Which features have the lowest and highest weights respectively?

# %%
importance = running.coef_

# %%
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: -0.37072
# Feature: 1, Score: 16.30020
# Feature: 2, Score: -18.37003
# Feature: 3, Score: -13.74075
# Feature: 4, Score: 25.83674
# Feature: 5, Score: 4.80316
# Feature: 6, Score: 2.79366
# Feature: 7, Score: 1.20498
# Feature: 8, Score: -1.60084
# Feature: 9, Score: 0.25751
# Feature: 10, Score: 7.36355
# Feature: 11, Score: 0.41165
# Feature: 12, Score: 1.04063
# Feature: 13, Score: -1.69279
# Feature: 14, Score: 9.99097
# Feature: 15, Score: -5.77886
# Feature: 16, Score: -21.14845
# Feature: 17, Score: -1.76268
# Feature: 18, Score: -11.07363
# Feature: 19, Score: 0.17019
# Feature: 20, Score: -1.09352
# Feature: 21, Score: 2.23042
# Feature: 22, Score: 0.20259
# Feature: 23, Score: 5.70139
# Feature: 24, Score: 0.01648
# Feature: 25, Score: 0.01648

# %% [markdown]
# ### Q: What is the Coefficient of Determination (in two decimal places)?

# %%
lr.score(X_train, Y_train)
# Out:
# 0.14471942308518737

# %% [markdown]
# ### Q: What is the Root Mean Squared Error (in three decimal places)?

# %%
r2_score(Y_test, pred)
# Out:
# 0.14890246319303524

# %% [markdown]
# ### Q: Train a ridge regression model with an alpha value of 0.4. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
model_r = Ridge(alpha = 0.4)

# %%
model_r.fit(X_train, Y_train)
# Out:
# Ridge(alpha=0.4)

# %%
pred_ridge = model_r.predict(X_test)

# %%
mean_squared_error(Y_test, pred_ridge)
# Out:
# 8768.543986942277

# %% [markdown]
# ### Q: Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
lasso_r = Lasso(alpha = 0.001)

# %%
lasso_tr = lasso_r.fit(X_train, Y_train)
# Out:
# /Users/onyekachukwuokonji/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.136e+06, tolerance: 1.464e+04
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_tr.n_features_in_
# Out:
# 26

# %% [markdown]
# ### Q: What is the new RMSE with the lasso regression? (Answer should be in three (3) decimal places)

# %%
lasso_pred = lasso_tr.predict(X_test)

# %%
mean_squared_error(Y_test, lasso_pred)
# Out:
# 8768.539068085514
